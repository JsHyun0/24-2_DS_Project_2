# %%
import pandas as pd
import matplotlib.pyplot as plt
from Visualization import *

# %%
train_loss_path = '../Data/v4_metrics_train_loss_97.csv'
valid_loss_path = '../Data/v4_metrics_valid_loss_97.csv'

# %%
visualize_loss(train_loss_path, valid_loss_path)
